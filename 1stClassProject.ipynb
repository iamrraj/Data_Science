# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("data"))
#importing libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('data/data.csv')
data.head(4)
# Out:
# ['.DS_Store', 'data.csv', 'testset.csv']
#             Currency   Code  Mid-rate
# 0  Australian Dollar  1 AUD    2.7405
# 1               Baht  1 THB    0.1144
# 2     Brazilian Real  1 BRL    1.0075
# 3      Bulgarian Lev  1 BGN    2.1960

# %%
data.loc[0:6,['Code','Mid-rate']]
# Out:
#       Code  Mid-rate
# 0    1 AUD    2.7405
# 1    1 THB    0.1144
# 2    1 BRL    1.0075
# 3    1 BGN    2.1960
# 4    1 CAD    2.8725
# 5  100 CLP    0.5567
# 6    1 CZK    0.1661

# %%
df = pd.DataFrame(data)
df.plot.box(grid='True')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
data.describe()
# Out:
#         Mid-rate
# count  35.000000
# mean    1.716274
# std     1.645539
# min     0.056700
# 25%     0.434950
# 50%     0.921000
# 75%     2.807100
# max     5.205900

# %%
data['Mid-rate'].hist(bins=50)

# %%
data.boxplot(column='Mid-rate', by='Code', figsize=(30,10))

# %%
temp3 = pd.crosstab(df['Code'], df['Mid-rate'])
temp3.plot(kind='bar',stacked=True, color=['red', 'green'], grid=False, figsize=(20,10))

# %%
data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Currency    0
# Code        0
# Mid-rate    0
# dtype: int64

# %%
data['Code'].value_counts()
# Out:
# 1 PHP        1
# 1 THB        1
# 1 GBP        1
# 1 BGN        1
# 1 HKD        1
# 100 KRW      1
# 1 AUD        1
# 1 NZD        1
# 1 XDR        1
# 100 HUF      1
# 1 NOK        1
# 1 RON        1
# 1 CAD        1
# 100 ISK      1
# 1 CZK        1
# 1 UAH        1
# 1 RUB        1
# 1 ILS        1
# 1 DKK        1
# 100 INR      1
# 1 MXN        1
# 1 CHF        1
# 1 TRY        1
# 1 SEK        1
# 1 EUR        1
# 10000 IDR    1
# 1 BRL        1
# 1 MYR        1
# 1 HRK        1
# 1 SGD        1
# 1 ZAR        1
# 1 USD        1
# 100 CLP      1
# 100 JPY      1
# 1 CNY        1
# Name: Code, dtype: int64
